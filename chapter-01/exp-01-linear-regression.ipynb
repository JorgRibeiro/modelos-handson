# %% [markdown]
# # Regressao Linear (Hands-On ML)
# Notebook equivalente ao script de regressao linear com visualizacao interativa no Jupyter.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
# Carregar e preparar os dados
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# %%
# Visualizar os dados
lifesat.plot(kind="scatter", grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

# %%
# Selecionar um modelo linear - Regressao Linear
model = LinearRegression()

# Treinar o modelo
model.fit(X, y)

# Fazer uma predicao de Chipre
X_new = [[37_655.2]] # PIB per capita de Chipre em 2020
print(model.predict(X_new))
# Out:
# [[6.30165767]]

# %%
# Selecionar um modelo linear - KNeighbors
model = KNeighborsRegressor(n_neighbors=3)

# Treinar o modelo
model.fit(X, y)

# Fazer uma predicao de Chipre
X_new = [[37_655.2]] # PIB per capita de Chipre em 2020
print(model.predict(X_new))
# Out:
# [[6.33333333]]
